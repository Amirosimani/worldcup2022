# %%
import numpy as np
from numpy import linalg as LA
from scipy.sparse import linalg as lg
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.preprocessing import normalize

# %matplotlib inline
# %load_ext autotime

# %% [markdown]
# ## 1-a

# %%
x_2016 = np.genfromtxt('/Users/Amiros/GitHub/Machine Learning for Data Science/hw5_markov_chaines/CFB2016_scores.csv', 
          delimiter=',', dtype=float)

team_names = pd.read_csv('/Users/Amiros/GitHub/Machine Learning for Data Science/hw5_markov_chaines/TeamNames.txt',
                        header = None)
# Out:
# time: 51.1 ms

# %%
a_index = x_2016[:,0] -1
b_index = x_2016[:,2] -1

a_score = x_2016[:,1]
b_score = x_2016[:,3]

a_indicator = np.where(a_score>b_score,1,0)
b_indicator = np.where(a_score<b_score,1,0)
# Out:
# time: 4.63 ms

# %%
M = np.zeros((760, 760))

M[tuple(a_index), tuple(a_index)] = M[tuple(a_index), tuple(a_index)] + a_indicator + a_score/(a_score+b_score)
M[tuple(b_index), tuple(b_index)] = M[tuple(b_index), tuple(b_index)] + b_indicator + b_score/(a_score+b_score)
M[tuple(a_index), tuple(b_index)] = M[tuple(a_index), tuple(b_index)] + b_indicator + b_score/(a_score+b_score)
M[tuple(b_index), tuple(a_index)] = M[tuple(b_index), tuple(a_index)] + a_indicator + b_score/(a_score+b_score)

# M_normalize = M/M.sum(axis=1)
M_normalize = normalize(M, norm='l1', axis=1)
# Out:
# time: 41.8 ms
# /Users/Amiros/anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:3: VisibleDeprecationWarning: non integer (and non boolean) array-likes will not be accepted as indices in the future
#   app.launch_new_instance()
# /Users/Amiros/anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:4: VisibleDeprecationWarning: non integer (and non boolean) array-likes will not be accepted as indices in the future
# /Users/Amiros/anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:5: VisibleDeprecationWarning: non integer (and non boolean) array-likes will not be accepted as indices in the future
# /Users/Amiros/anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:6: VisibleDeprecationWarning: non integer (and non boolean) array-likes will not be accepted as indices in the future

# %%
M_normalize
# Out:
# array([[ 0.11328787,  0.        ,  0.        , ...,  0.        ,
#          0.        ,  0.        ],
#        [ 0.        ,  0.13190717,  0.        , ...,  0.        ,
#          0.        ,  0.        ],
#        [ 0.        ,  0.        ,  0.07762666, ...,  0.        ,
#          0.        ,  0.        ],
#        ...,
#        [ 0.        ,  0.        ,  0.        , ...,  0.06665938,
#          0.        ,  0.        ],
#        [ 0.        ,  0.        ,  0.        , ...,  0.        ,
#          0.13313686,  0.        ],
#        [ 0.        ,  0.        ,  0.        , ...,  0.        ,
#          0.        ,  0.12379859]])
# time: 4.98 ms

# %%
# function to calculate state at t
def update_w(w_0, t):
    w_arr = []
    w = w_0
    for i in range(t):
        w = np.dot(w, M_normalize)
    w_arr = pd.DataFrame(w.T, index= None, columns = ['score'])
    w_arr['team'] = team_names
    return w_arr
# Out:
# time: 5.39 ms

# %%
np.random.seed(42)
w_0 = np.random.uniform(low=0.0, high=1.0, size=(1,760))
w_0 = normalize(w_0, norm='l1')

w_10 = update_w(w_0, 10)
w_10.columns.name = 't=10'

w_100 = update_w(w_0, 100)
w_100.columns.name = 't=100'

w_1000 = update_w(w_0, 1000)
w_1000.columns.name = 't=1000'

w_10000 = update_w(w_0, 10000)
w_10000.columns.name = 't=10000'
# Out:
# time: 3.16 s

# %%
# function to display all tables side by side
def multi_column_df_display(list_dfs, cols=4):
    html_table = "<table style='width:100%; border:0px'>{content}</table>"
    html_row = "<tr style='border:0px'>{content}</tr>"
    html_cell = "<td style='width:{width}%;vertical-align:top;border:0px'>{{content}}</td>"
    html_cell = html_cell.format(width=100/cols)

    cells = [ html_cell.format(content=df.to_html()) for df in list_dfs ]
    cells += (cols - (len(list_dfs)%cols)) * [html_cell.format(content="")] # pad
    rows = [ html_row.format(content="".join(cells[i:i+cols])) for i in range(0,len(cells),cols)]
    display(HTML(html_table.format(content="".join(rows))))

list_dfs = []
list_dfs.append( w_10.sort('score', ascending=False).head(25) )
list_dfs.append( w_100.sort('score', ascending=False).head(25) )
list_dfs.append( w_1000.sort('score', ascending=False).head(25) )
list_dfs.append( w_10000.sort('score', ascending=False).head(25) )

multi_column_df_display(list_dfs)
# Out:
# <table style='width:100%; border:0px'><tr style='border:0px'><td style='width:25.0%;vertical-align:top;border:0px'><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>t=10</th>
#       <th>score</th>
#       <th>team</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>440</th>
#       <td>0.005732</td>
#       <td>NW Missouri St</td>
#     </tr>
#     <tr>
#       <th>370</th>
#       <td>0.005631</td>
#       <td>Mary Hardin-Baylor</td>
#     </tr>
#     <tr>
#       <th>133</th>
#       <td>0.005050</td>
#       <td>Clemson</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>0.004624</td>
#       <td>Alabama</td>
#     </tr>
#     <tr>
#       <th>301</th>
#       <td>0.004388</td>
#       <td>John Carroll</td>
#     </tr>
#     <tr>
#       <th>668</th>
#       <td>0.004224</td>
#       <td>UW-Oshkosh</td>
#     </tr>
#     <tr>
#       <th>673</th>
#       <td>0.004054</td>
#       <td>UW-Whitewater</td>
#     </tr>
#     <tr>
#       <th>299</th>
#       <td>0.003724</td>
#       <td>James Madison</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>0.003652</td>
#       <td>Alfred</td>
#     </tr>
#     <tr>
#       <th>219</th>
#       <td>0.003644</td>
#       <td>Florida St</td>
#     </tr>
#     <tr>
#       <th>230</th>
#       <td>0.003612</td>
#       <td>Frostburg St</td>
#     </tr>
#     <tr>
#       <th>210</th>
#       <td>0.003595</td>
#       <td>Ferris St</td>
#     </tr>
#     <tr>
#       <th>598</th>
#       <td>0.003593</td>
#       <td>St Francis IN</td>
#     </tr>
#     <tr>
#       <th>435</th>
#       <td>0.003501</td>
#       <td>Mount Union</td>
#     </tr>
#     <tr>
#       <th>94</th>
#       <td>0.003392</td>
#       <td>California PA</td>
#     </tr>
#     <tr>
#       <th>714</th>
#       <td>0.003349</td>
#       <td>Wesley</td>
#     </tr>
#     <tr>
#       <th>457</th>
#       <td>0.003284</td>
#       <td>North Alabama</td>
#     </tr>
#     <tr>
#       <th>564</th>
#       <td>0.003276</td>
#       <td>Shepherd</td>
#     </tr>
#     <tr>
#       <th>465</th>
#       <td>0.003239</td>
#       <td>North Dakota St</td>
#     </tr>
#     <tr>
#       <th>649</th>
#       <td>0.003225</td>
#       <td>Trinity CT</td>
#     </tr>
#     <tr>
#       <th>48</th>
#       <td>0.003189</td>
#       <td>Baker</td>
#     </tr>
#     <tr>
#       <th>581</th>
#       <td>0.003177</td>
#       <td>Southern Cal</td>
#     </tr>
#     <tr>
#       <th>608</th>
#       <td>0.003138</td>
#       <td>St Thomas</td>
#     </tr>
#     <tr>
#       <th>704</th>
#       <td>0.003099</td>
#       <td>Washington</td>
#     </tr>
#     <tr>
#       <th>759</th>
#       <td>0.003066</td>
#       <td>Youngstown St</td>
#     </tr>
#   </tbody>
# </table></td><td style='width:25.0%;vertical-align:top;border:0px'><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>t=100</th>
#       <th>score</th>
#       <th>team</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>440</th>
#       <td>0.007777</td>
#       <td>NW Missouri St</td>
#     </tr>
#     <tr>
#       <th>133</th>
#       <td>0.007718</td>
#       <td>Clemson</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>0.006927</td>
#       <td>Alabama</td>
#     </tr>
#     <tr>
#       <th>219</th>
#       <td>0.005425</td>
#       <td>Florida St</td>
#     </tr>
#     <tr>
#       <th>581</th>
#       <td>0.004767</td>
#       <td>Southern Cal</td>
#     </tr>
#     <tr>
#       <th>704</th>
#       <td>0.004581</td>
#       <td>Washington</td>
#     </tr>
#     <tr>
#       <th>751</th>
#       <td>0.004581</td>
#       <td>Wisconsin</td>
#     </tr>
#     <tr>
#       <th>299</th>
#       <td>0.004527</td>
#       <td>James Madison</td>
#     </tr>
#     <tr>
#       <th>506</th>
#       <td>0.004457</td>
#       <td>Penn State</td>
#     </tr>
#     <tr>
#       <th>492</th>
#       <td>0.004424</td>
#       <td>Oklahoma</td>
#     </tr>
#     <tr>
#       <th>370</th>
#       <td>0.004343</td>
#       <td>Mary Hardin-Baylor</td>
#     </tr>
#     <tr>
#       <th>215</th>
#       <td>0.004332</td>
#       <td>Florida</td>
#     </tr>
#     <tr>
#       <th>511</th>
#       <td>0.004272</td>
#       <td>Pittsburgh</td>
#     </tr>
#     <tr>
#       <th>489</th>
#       <td>0.004212</td>
#       <td>Ohio State</td>
#     </tr>
#     <tr>
#       <th>690</th>
#       <td>0.004210</td>
#       <td>Virginia Tech</td>
#     </tr>
#     <tr>
#       <th>210</th>
#       <td>0.004179</td>
#       <td>Ferris St</td>
#     </tr>
#     <tr>
#       <th>611</th>
#       <td>0.004151</td>
#       <td>Stanford</td>
#     </tr>
#     <tr>
#       <th>389</th>
#       <td>0.004144</td>
#       <td>Michigan</td>
#     </tr>
#     <tr>
#       <th>387</th>
#       <td>0.004133</td>
#       <td>Miami FL</td>
#     </tr>
#     <tr>
#       <th>465</th>
#       <td>0.004024</td>
#       <td>North Dakota St</td>
#     </tr>
#     <tr>
#       <th>202</th>
#       <td>0.003966</td>
#       <td>Emporia St</td>
#     </tr>
#     <tr>
#       <th>628</th>
#       <td>0.003963</td>
#       <td>Tennessee</td>
#     </tr>
#     <tr>
#       <th>242</th>
#       <td>0.003959</td>
#       <td>Georgia Tech</td>
#     </tr>
#     <tr>
#       <th>140</th>
#       <td>0.003950</td>
#       <td>Colorado</td>
#     </tr>
#     <tr>
#       <th>458</th>
#       <td>0.003947</td>
#       <td>North Carolina</td>
#     </tr>
#   </tbody>
# </table></td><td style='width:25.0%;vertical-align:top;border:0px'><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>t=1000</th>
#       <th>score</th>
#       <th>team</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>133</th>
#       <td>0.010299</td>
#       <td>Clemson</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>0.009226</td>
#       <td>Alabama</td>
#     </tr>
#     <tr>
#       <th>440</th>
#       <td>0.008495</td>
#       <td>NW Missouri St</td>
#     </tr>
#     <tr>
#       <th>219</th>
#       <td>0.007207</td>
#       <td>Florida St</td>
#     </tr>
#     <tr>
#       <th>581</th>
#       <td>0.006369</td>
#       <td>Southern Cal</td>
#     </tr>
#     <tr>
#       <th>751</th>
#       <td>0.006116</td>
#       <td>Wisconsin</td>
#     </tr>
#     <tr>
#       <th>704</th>
#       <td>0.006103</td>
#       <td>Washington</td>
#     </tr>
#     <tr>
#       <th>506</th>
#       <td>0.005960</td>
#       <td>Penn State</td>
#     </tr>
#     <tr>
#       <th>492</th>
#       <td>0.005890</td>
#       <td>Oklahoma</td>
#     </tr>
#     <tr>
#       <th>215</th>
#       <td>0.005776</td>
#       <td>Florida</td>
#     </tr>
#     <tr>
#       <th>299</th>
#       <td>0.005770</td>
#       <td>James Madison</td>
#     </tr>
#     <tr>
#       <th>511</th>
#       <td>0.005684</td>
#       <td>Pittsburgh</td>
#     </tr>
#     <tr>
#       <th>489</th>
#       <td>0.005632</td>
#       <td>Ohio State</td>
#     </tr>
#     <tr>
#       <th>690</th>
#       <td>0.005587</td>
#       <td>Virginia Tech</td>
#     </tr>
#     <tr>
#       <th>389</th>
#       <td>0.005542</td>
#       <td>Michigan</td>
#     </tr>
#     <tr>
#       <th>611</th>
#       <td>0.005535</td>
#       <td>Stanford</td>
#     </tr>
#     <tr>
#       <th>387</th>
#       <td>0.005498</td>
#       <td>Miami FL</td>
#     </tr>
#     <tr>
#       <th>628</th>
#       <td>0.005281</td>
#       <td>Tennessee</td>
#     </tr>
#     <tr>
#       <th>140</th>
#       <td>0.005264</td>
#       <td>Colorado</td>
#     </tr>
#     <tr>
#       <th>242</th>
#       <td>0.005258</td>
#       <td>Georgia Tech</td>
#     </tr>
#     <tr>
#       <th>458</th>
#       <td>0.005190</td>
#       <td>North Carolina</td>
#     </tr>
#     <tr>
#       <th>494</th>
#       <td>0.005131</td>
#       <td>Oklahoma St</td>
#     </tr>
#     <tr>
#       <th>321</th>
#       <td>0.005064</td>
#       <td>LSU</td>
#     </tr>
#     <tr>
#       <th>465</th>
#       <td>0.005056</td>
#       <td>North Dakota St</td>
#     </tr>
#     <tr>
#       <th>239</th>
#       <td>0.004832</td>
#       <td>Georgia</td>
#     </tr>
#   </tbody>
# </table></td><td style='width:25.0%;vertical-align:top;border:0px'><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>t=10000</th>
#       <th>score</th>
#       <th>team</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>133</th>
#       <td>0.010313</td>
#       <td>Clemson</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>0.009238</td>
#       <td>Alabama</td>
#     </tr>
#     <tr>
#       <th>440</th>
#       <td>0.008498</td>
#       <td>NW Missouri St</td>
#     </tr>
#     <tr>
#       <th>219</th>
#       <td>0.007216</td>
#       <td>Florida St<
# time: 44.9 ms

# %% [markdown]
# ## 1-b

# %%
u = np.real(lg.eigs(M, k=1, sigma=1.0)[1])

# eig=np.real(lg.eigs(M.transpose(),k=1,sigma=1.0)[1].transpose()[0])
w_stationary = u.T/np.sum(u)
# Out:
# time: 56.3 ms

# %%
w_st_normalized = normalize(w_stationary, norm='l1')
# Out:
# time: 2.45 ms

# %%
# def print_w(w_0, w_stationary, t=2):
#     w = w_0
#     x = []
#     for i in range(t):
#         w = np.dot(w, M_normalize)
#         w = normalize(w, norm='l1')
#         x.append(LA.norm(w_stationary-w, ord=1))
    
#     plt.figure(num=None, figsize=(10, 10), dpi=80)
#     plt.plot(x, linewidth=2)

# print_w(w_0, w_st_normalized, t=10000)
# Out:
# time: 1.87 ms

# %% [markdown]
# ## 2-a

# %%
# load the txt file
with open('nyt_data.csv') as f:
    content = f.readlines()
content = [x.strip() for x in content]
# Out:
# time: 37.1 ms

# %%
# initialize X matrix to the size of 3012 words by 8447 documents <3012X8447>
X = np.zeros((3012, 8447), dtype =float)
# Out:
# time: 1.6 ms

# %%
# populate X matrix with the values from the loaded file
# where Xij is the number of times word i appears in document j
for i in range(len(content)):    
    doc = content[i].split(",") 
    
    for element in doc:
        parts = element.split(':')
        parts = list(map(int, parts))
        X[parts[0]-1, i] = parts[1]
# Out:
# time: 2.11 s

# %%
k = 25
t = 100

W = np.random.uniform(low=1, high=2, size=(3012,25))
H = np.random.uniform(low=1, high=2, size=(25,8447))
# Out:
# time: 11.4 ms

# %%
L = []
for i in range(t):
    H = np.multiply(H, W.T.dot(X)/((W.T.dot(W).dot(H)) + 10**-16))
    W = np.multiply(W, X.dot(H.T)/((W.dot(H).dot(H.T)) + 10**-16))
    l = np.multiply(X, np.log(1/W.dot(H))) + W.dot(H)
    L.append(np.nansum(l))
# Out:
# time: 3min 1s

# %%
plt.figure(num=None, figsize=(10, 10), dpi=80)

plt.plot(L)
plt.xlabel("iteration")
plt.ylabel("Divergence Penalty Objective Function")
# Out:
# time: 308 ms

# %% [markdown]
# ## 2-b

# %%
with open('nyt_vocab.dat') as l:
    word_list = l.readlines()
word_list = [x.strip() for x in word_list] 
word_list_arr = np.asarray(word_list)
# Out:
# time: 30.5 ms

# %%
# normailzie each column to sum to 1
W_norm_df = pd.DataFrame(normalize(W, norm='l1', axis=0))

# rename columns
col_names = []
for i in range(1,26):
    col_names.append('topic_'+ str(i))
    
W_norm_df.columns = col_names
# Out:
# time: 7.22 ms

# %%
# function to sort pandas columns
def sorted(s, num):
    tmp = s.order(ascending=False)[:num]
    tmp.index = range(num)
    return tmp

# function to get the index of N largest values
def get_index(x, N):
    tmp = np.argsort(-x)[:N]
    return tmp
# Out:
# time: 4.63 ms

# %%
top_values = W_norm_df.apply(lambda x: sorted(x, 10))
top_index = W_norm_df.apply(lambda x: get_index(x, 10))
# Out:
# time: 63.9 ms

# %%
def word_values(topic):
    word = []
    value = []
    for i in top_index[topic]:
        word.append(word_list[i])
    value = top_values[topic].tolist()
    dictionary = dict(zip(word, value))
    return dictionary
### need to sort the dictionary #####
# Out:
# time: 4.62 ms

# %%
final_list = []
s = []
d = []

for topic in col_names:
    d = word_values(topic)
    s = pd.DataFrame(pd.Series(d, name='Value'))
    s.columns.name = topic
    s = s.sort('Value', ascending=False)
    final_list.append(s)
# Out:
# time: 31.4 ms

# %%
multi_column_df_display(final_list, 5)
# Out:
# <table style='width:100%; border:0px'><tr style='border:0px'><td style='width:20.0%;vertical-align:top;border:0px'><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>topic_1</th>
#       <th>Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>serve</th>
#       <td>0.010419</td>
#     </tr>
#     <tr>
#       <th>add</th>
#       <td>0.009723</td>
#     </tr>
#     <tr>
#       <th>minute</th>
#       <td>0.009701</td>
#     </tr>
#     <tr>
#       <th>pepper</th>
#       <td>0.008833</td>
#     </tr>
#     <tr>
#       <th>oil</th>
#       <td>0.008663</td>
#     </tr>
#     <tr>
#       <th>food</th>
#       <td>0.008417</td>
#     </tr>
#     <tr>
#       <th>cup</th>
#       <td>0.008387</td>
#     </tr>
#     <tr>
#       <th>cook</th>
#       <td>0.008364</td>
#     </tr>
#     <tr>
#       <th>water</th>
#       <td>0.007960</td>
#     </tr>
#     <tr>
#       <th>sauce</th>
#       <td>0.007857</td>
#     </tr>
#   </tbody>
# </table></td><td style='width:20.0%;vertical-align:top;border:0px'><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>topic_2</th>
#       <th>Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>thing</th>
#       <td>0.018797</td>
#     </tr>
#     <tr>
#       <th>ask</th>
#       <td>0.016242</td>
#     </tr>
#     <tr>
#       <th>tell</th>
#       <td>0.015819</td>
#     </tr>
#     <tr>
#       <th>lot</th>
#       <td>0.011478</td>
#     </tr>
#     <tr>
#       <th>feel</th>
#       <td>0.011283</td>
#     </tr>
#     <tr>
#       <th>job</th>
#       <td>0.009062</td>
#     </tr>
#     <tr>
#       <th>really</th>
#       <td>0.008693</td>
#     </tr>
#     <tr>
#       <th>big</th>
#       <td>0.007845</td>
#     </tr>
#     <tr>
#       <th>keep</th>
#       <td>0.007564</td>
#     </tr>
#     <tr>
#       <th>little</th>
#       <td>0.007280</td>
#     </tr>
#   </tbody>
# </table></td><td style='width:20.0%;vertical-align:top;border:0px'><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>topic_3</th>
#       <th>Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>official</th>
#       <td>0.012913</td>
#     </tr>
#     <tr>
#       <th>leader</th>
#       <td>0.008236</td>
#     </tr>
#     <tr>
#       <th>government</th>
#       <td>0.007995</td>
#     </tr>
#     <tr>
#       <th>military</th>
#       <td>0.007910</td>
#     </tr>
#     <tr>
#       <th>force</th>
#       <td>0.007810</td>
#     </tr>
#     <tr>
#       <th>meeting</th>
#       <td>0.007302</td>
#     </tr>
#     <tr>
#       <th>war</th>
#       <td>0.006874</td>
#     </tr>
#     <tr>
#       <th>agreement</th>
#       <td>0.005808</td>
#     </tr>
#     <tr>
#       <th>meet</th>
#       <td>0.005773</td>
#     </tr>
#     <tr>
#       <th>peace</th>
#       <td>0.005715</td>
#     </tr>
#   </tbody>
# </table></td><td style='width:20.0%;vertical-align:top;border:0px'><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>topic_4</th>
#       <th>Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>study</th>
#       <td>0.010329</td>
#     </tr>
#     <tr>
#       <th>problem</th>
#       <td>0.007883</td>
#     </tr>
#     <tr>
#       <th>patient</th>
#       <td>0.007883</td>
#     </tr>
#     <tr>
#       <th>cause</th>
#       <td>0.007235</td>
#     </tr>
#     <tr>
#       <th>drug</th>
#       <td>0.007164</td>
#     </tr>
#     <tr>
#       <th>health</th>
#       <td>0.006876</td>
#     </tr>
#     <tr>
#       <th>doctor</th>
#       <td>0.006861</td>
#     </tr>
#     <tr>
#       <th>research</th>
#       <td>0.005943</td>
#     </tr>
#     <tr>
#       <th>risk</th>
#       <td>0.005659</td>
#     </tr>
#     <tr>
#       <th>result</th>
#       <td>0.005585</td>
#     </tr>
#   </tbody>
# </table></td><td style='width:20.0%;vertical-align:top;border:0px'><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>topic_5</th>
#       <th>Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>political</th>
#       <td>0.015916</td>
#     </tr>
#     <tr>
#       <th>campaign</th>
#       <td>0.015787</td>
#     </tr>
#     <tr>
#       <th>vote</th>
#       <td>0.015097</td>
#     </tr>
#     <tr>
#       <th>party</th>
#       <td>0.013909</td>
#     </tr>
#     <tr>
#       <th>republican</th>
#       <td>0.013585</td>
#     </tr>
#     <tr>
#       <th>election</th>
#       <td>0.013088</td>
#     </tr>
#     <tr>
#       <th>candidate</th>
#       <td>0.012822</td>
#     </tr>
#     <tr>
#       <th>democratic</th>
#       <td>0.011738</td>
#     </tr>
#     <tr>
#       <th>state</th>
#       <td>0.011346</td>
#     </tr>
#     <tr>
#       <th>voter</th>
#       <td>0.010594</td>
#     </tr>
#   </tbody>
# </table></td></tr><tr style='border:0px'><td style='width:20.0%;vertical-align:top;border:0px'><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>topic_6</th>
#       <th>Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>pay</th>
#       <td>0.020127</td>
#     </tr>
#     <tr>
#       <th>money</th>
#       <td>0.016355</td>
#     </tr>
#     <tr>
#       <th>program</th>
#       <td>0.015946</td>
#     </tr>
#     <tr>
#       <th>plan</th>
#       <td>0.015606</td>
#     </tr>
#     <tr>
#       <th>budget</th>
#       <td>0.014289</td>
#     </tr>
#     <tr>
#       <th>tax</th>
#       <td>0.013870</td>
#     </tr>
#     <tr>
#       <th>cut</th>
#       <td>0.013712</td>
#     </tr>
#     <tr>
#       <th>state</th>
#       <td>0.013333</td>
#     </tr>
#     <tr>
#       <th>cost</th>
#       <td>0.012931</td>
#     </tr>
#     <tr>
#       <th>bill</th>
#       <td>0.011553</td>
#     </tr>
#   </tbody>
# </table></td><td style='width:20.0%;vertical-align:top;border:0px'><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>topic_7</th>
#       <th>Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>executive</th>
#       <td>0.038850</td>
#     </tr>
#     <tr>
#       <th>president</th>
#       <td>0.036043</td>
#     </tr>
#     <tr>
#       <th>chief</th>
#       <td>0.026139</td>
#     </tr>
#     <tr>
#       <th>yesterday</th>
#       <td>0.021133</td>
#     </tr>
#     <tr>
#       <th>vice</th>
#       <td>0.017503</td>
#     </tr>
#     <tr>
#       <th>chairman</th>
#       <td>0.017108</td>
#     </tr>
#     <tr>
#       <th>company</th>
#       <td>0.016972</td>
#     </tr>
#     <tr>
#       <th>announce</th>
#       <td>0.013662</td>
#     </tr>
#     <tr>
#       <th>director</th>
#       <td>0.013359</td>
#     </tr>
#     <tr>
#       <th>name</th>
#       <td>0.011123</td>
#     </tr>
#   </tbody>
# </table></td><td style='width:20.0%;vertical-align:top;border:0px'><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>topic_8</th>
#       <th>Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>company</th>
#       <td>0.043303</td>
#     </tr>
#     <tr>
#       <th>industry</th>
#       <td>0.017359</td>
#     </tr>
#     <tr>
#       <th>computer</th>
#       <td>0.013774</td>
#     </tr>
#     <tr>
#       <th>technology</th>
#       <td>0.013002</td>
#     </tr>
#     <tr>
#       <th>product</th>
#       <td>0.011701</td>
#     </tr>
#     <tr>
#       <th>system</th>
#       <td>0.011053</td>
#     </tr>
#     <tr>
#       <th>business</th>
#       <td>0.011037</td>
#     </tr>
#     <tr>
#       <th>base</th>
#       <td>0.006971</td>
#     </tr>
#     <tr>
#       <th>large</th>
#       <td>0.006968</td>
#     </tr>
#     <tr>
#       <th>create</th>
#       <td>0.006873</td>
#     </tr>
#   </tbody>
# </table></td><td style='width:20.0%;vertical-align:top;border:0px'><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>topic_9</th>
#       <th>Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>case</th>
#       <td>0.021650</td>
#     </tr>
#     <tr>
#       <th>lawyer</th>
#       <td>0.016169</td>
#     </tr>
#     <tr>
#       <th>court</th>
#       <td>0.015760</td>
#     </tr>
#     <tr>
#       <th>law</th>
#       <td>0.014264</td>
#     </tr>
#     <tr>
#       <th>charge</th>
#       <td>0.012109</td>
#     </tr>
#     <tr>
#       <th>judge</th>
#       <td>0.010726</td>
#     </tr>
#     <tr>
#       <th>trial</th>
#       <td>0.009028</td>
#     </tr>
#     <tr>
#       <th>state</th>
#       <td>0.009021</td>
#     </tr>
#     <tr>
#       <th>legal</th>
#       <td>0.008365</td>
#     </tr>
#     <tr>
#       <th>prosecutor</th>
#       <td>0.0077
# time: 45.4 ms
